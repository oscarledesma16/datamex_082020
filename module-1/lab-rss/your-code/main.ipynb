# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
reddit = feedparser.parse(url)
print(reddit['feed'])
# Out:
# {'title': 'Radar', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://feeds.feedburner.com/oreilly/radar/atom', 'value': 'Radar'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.oreilly.com/radar'}, {'rel': 'self', 'type': 'application/rss+xml', 'href': 'http://feeds.feedburner.com/oreilly/radar/atom'}, {'rel': 'hub', 'href': 'http://pubsubhubbub.appspot.com/', 'type': 'text/html'}], 'link': 'https://www.oreilly.com/radar', 'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology', 'subtitle_detail': {'type': 'text/html', 'language': None, 'base': 'http://feeds.feedburner.com/oreilly/radar/atom', 'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'}, 'updated': 'Wed, 19 Aug 2020 11:44:07 +0000', 'updated_parsed': time.struct_time(tm_year=2020, tm_mon=8, tm_mday=19, tm_hour=11, tm_min=44, tm_sec=7, tm_wday=2, tm_yday=232, tm_is
# ...

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
reddit.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
reddit.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print (reddit.feed.title)
print (reddit.feed.subtitle)
print (reddit.feed.updated)
print (reddit.feed.link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# Wed, 19 Aug 2020 11:44:07 +0000
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
entries = reddit.entries[0]
entries
# Out:
# {'title': 'Four Short Links: 19 August 2020',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#   'value': 'Four Short Links: 19 August 2020'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-JJuYwrweOg/'}],
#  'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-JJuYwrweOg/',
#  'comments': 'https://www.oreilly.com/radar/four-short-links-19-august-2020/#respond',
#  'published': 'Wed, 19 Aug 2020 11:44:06 +0000',
#  'published_parsed': time.struct_time(tm_year=2020, tm_mon=8, tm_mday=19, tm_hour=11, tm_min=44, tm_sec=6, tm_wday=2, tm_yday=232, tm_isdst=0),
#  'authors': [{'name': 'Nat Torkington'}],
#  'author': 'Nat Torkington',
#  'author_detail': {'name': 'Nat Torkington'},
#  'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#   {'term': 'Signals', 'scheme': None, 'label': None}],
# ...

# %%
entries1 = reddit.entries[0].keys()
entries1
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %%
lst_entr = 0
for i in entries1:
    lst_entr += 1
lst_entr
# Out:
# 19

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
reddit.entries[4].comments
# Out:
# 'https://www.oreilly.com/radar/four-short-links-11-aug-2020/#respond'

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [reddit.entries[i].title for i in range(len(reddit.entries))]
print(str(titles))
# Out:
# ['Four Short Links: 19 August 2020', 'Why Best-of-Breed is a Better Choice than All-in-One Platforms for Data Science', 'Four short links: 14 August 2020', 'The Least Liked Programming Languages', 'Four short links: 11 Aug 2020', 'Four short links: 7 Aug 2020', 'Four short links: 5 August 2020', 'Radar trends to watch: August 2020', 'Four short links: 31 July 2020', 'Four short links: 30 July 2020', 'Four short links: 29 July 2020', 'Bringing an AI Product to Market', 'Power, Harms, and Data', 'Four short links: 27 July 2020', 'Four short links: 24 July 2020', 'Four short links: 26 July 2020', 'Four short links: 22 July 2020', 'AI, Protests, and Justice', 'Four short links: 21 July 2020', 'Four short links: 20 July 2020', 'Four short links: 17 July 2020', 'Four short links: 16 July 2020', 'Microservices Adoption in 2020', 'Four short links: 15 July 2020', 'Society-Centered Design', 'Four short links: 14 July 2020', 'Four short links: 13 July 2020', 'Four short links: 10 July 2020', '
# ...

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
import re

# %%
lst_titles = 0
for i in titles:
    lst_titles += 1
lst_titles
# Out:
# 60

# %%
cadena = " ".join(titles)
cadena
# Out:
# 'Four Short Links: 19 August 2020 Why Best-of-Breed is a Better Choice than All-in-One Platforms for Data Science Four short links: 14 August 2020 The Least Liked Programming Languages Four short links: 11 Aug 2020 Four short links: 7 Aug 2020 Four short links: 5 August 2020 Radar trends to watch: August 2020 Four short links: 31 July 2020 Four short links: 30 July 2020 Four short links: 29 July 2020 Bringing an AI Product to Market Power, Harms, and Data Four short links: 27 July 2020 Four short links: 24 July 2020 Four short links: 26 July 2020 Four short links: 22 July 2020 AI, Protests, and Justice Four short links: 21 July 2020 Four short links: 20 July 2020 Four short links: 17 July 2020 Four short links: 16 July 2020 Microservices Adoption in 2020 Four short links: 15 July 2020 Society-Centered Design Four short links: 14 July 2020 Four short links: 13 July 2020 Four short links: 10 July 2020 Automated Coding and the Future of Programming Four short links: 9 July 2020 Four sho
# ...

# %%
frec = re.findall(r'Four short links: \w+\s\w+\s\w+',cadena)

# %%
lst_four = 0
for i in frec:
    lst_four += 1
lst_four
# Out:
# 43

# %%
porcent = (lst_four * 100)/lst_titles
print(f'Total porcentaje: %{porcent}')
# Out:
# Total porcentaje: %71.66666666666667

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(reddit.entries)
df
# Out:
#                                                 title  \
# 0                    Four Short Links: 19 August 2020
# 1   Why Best-of-Breed is a Better Choice than All-...
# 2                    Four short links: 14 August 2020
# 3               The Least Liked Programming Languages
# 4                       Four short links: 11 Aug 2020
# 5                        Four short links: 7 Aug 2020
# 6                     Four short links: 5 August 2020
# 7                  Radar trends to watch: August 2020
# 8                      Four short links: 31 July 2020
# 9                      Four short links: 30 July 2020
# 10                     Four short links: 29 July 2020
# 11                   Bringing an AI Product to Market
# 12                             Power, Harms, and Data
# 13                     Four short links: 27 July 2020
# 14                     Four short links: 24 July 2020
# 15                     Four short links: 26 July 2020
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                                              author  entries
# 6                                    Nat Torkington       45
# 4                                     Mike Loukides        9
# 0      Adam Jacob, Nat Torkington and Mike Loukides        1
# 1                               Hugo Bowne-Anderson        1
# 2  Justin Norman, Peter Skomoroch and Mike Loukides        1
# 3           Matthew Rocklin and Hugo Bowne-Anderson        1
# 5                    Mike Loukides and Steve Swoyer        1
# 7                                        Sarah Gold        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
# Out:
#                                                 title  \
# 1   Why Best-of-Breed is a Better Choice than All-...
# 28     Automated Coding and the Future of Programming
# 53            Machine Learning and the Production Gap
# 3               The Least Liked Programming Languages
# 47                Decision-Making in a Time of Crisis
# 7                  Radar trends to watch: August 2020
# 0                    Four Short Links: 19 August 2020
# 11                   Bringing an AI Product to Market
# 2                    Four short links: 14 August 2020
# 35                   Radar trends to watch: July 2020
# 55                   Radar trends to watch: June 2020
# 45                    Four short links: June 19, 2020
# 6                     Four short links: 5 August 2020
# 8                      Four short links: 31 July 2020
# 9                      Four short links: 30 July 2020
# 44                     Four short links: 22 June 2020
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."
